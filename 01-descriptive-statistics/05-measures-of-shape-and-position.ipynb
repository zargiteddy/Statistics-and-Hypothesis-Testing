# %% [markdown]
# # Measures of Shape and Position

# %%
import pandas as pd

# %%
data = pd.read_csv("employee.csv")
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
import scipy.stats as stats

# %%
# calculate skewness and kurtosis

salary_skewness = stats.skew(data['MonthlyIncome'])
salary_kurtosis = stats.kurtosis(data['MonthlyIncome'])

print("Skewness of salary:", salary_skewness)
print("Kurtosis of salary:", salary_kurtosis)
# Out:
# Skewness of salary: 1.3684185123330814
# Kurtosis of salary: 0.9977379294765711

# %% [markdown]
# ### Percentiles and Quartiles

# %%
import numpy as np

# %%
#calculate percentiles
percentiles = np.percentile(data['MonthlyIncome'], [15, 45, 65])

#calculate quartiles
quartiles = np.percentile(data['MonthlyIncome'], [25, 50, 75])

print("Percentiles:")
print("15th percentile:", percentiles[0])
print("45th percentile (median):", percentiles[1])
print("65th percentile:", percentiles[2])

print("\nQuartiles:")
print("Q1 (25th percentile):", quartiles[0])
print("Q2 (50th percentile):", quartiles[1])
print("Q3 (75th percentile):", quartiles[2])
# Out:
# Percentiles:
# 15th percentile: 2476.7
# 45th percentile (median): 4554.1
# 65th percentile: 6348.7
#
# Quartiles:
# Q1 (25th percentile): 2911.0
# Q2 (50th percentile): 4919.0
# Q3 (75th percentile): 8379.0
